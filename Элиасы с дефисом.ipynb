# %% [markdown]
# <a href="https://colab.research.google.com/github/Vakhranev/Gramota/blob/main/%D0%AD%D0%BB%D0%B8%D0%B0%D1%81%D1%8B%20%D1%81%20%D0%B4%D0%B5%D1%84%D0%B8%D1%81%D0%BE%D0%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
from google.colab import drive

# Подключаем Google Drive
drive.mount('/content/drive')

# Путь к Google Drive
drive_path = '/content/drive/My Drive'
# Путь к локальному клону репозитория GitLab в Google Drive
repo_path = os.path.join(drive_path, 'gramota-generation')

# GitLab персональный токен доступа
gitlab_token = 'glpat-LPmZie5sw9HTMphcs2BP'

# Если репозиторий ещё не клонирован, клонируем его с использованием токена
if not os.path.exists(repo_path):
    # !git clone https://oauth2:{gitlab_token}@gitlab.gramota.ru/gramotaprojects/gramota-generation.git "{repo_path}"

# Путь к файлу notletter.csv
csv_file = os.path.join('notletter.csv')
# Путь к файлу словаря в репозитории
dictionary_file = os.path.join(repo_path, 'opensearch/indexing/alias_titles_slovari.txt')

# Проверяем, что файл словаря существует
if not os.path.exists(dictionary_file):
    raise FileNotFoundError(f"{dictionary_file} не найден. Проверьте, что репозиторий клонирован корректно.")

# Шаг 1: Извлечение слов с дефисом из файла CSV
df = pd.read_csv(csv_file)
defis_words = df[df['name'].str.contains('-')]['name'].tolist()
no_defis_words = df[~df['name'].str.contains('-')]['name'].tolist()

# Шаг 2: Создание вариантов неправильного написания
def generate_incorrect_variants(word):
    variants = [word.replace('-', ''), word.replace('-', ' ')]
    return f"{word}: {', '.join(variants)};"

incorrect_variants = [generate_incorrect_variants(word) for word in defis_words]

# Шаг 3: Чтение существующего словаря и добавление новых слов
with open(dictionary_file, 'r', encoding='utf-8') as file:
    existing_words = file.readlines()

existing_words_set = set(word.split(':')[0].strip() for word in existing_words)
new_entries = [variant for variant in incorrect_variants if variant.split(':')[0].strip() not in existing_words_set]

if new_entries:
    with open(dictionary_file, 'a', encoding='utf-8') as file:
        for entry in new_entries:
            file.write(f"\n{entry}")

# Шаг 4: Сохранение слов без дефиса в отдельный файл
no_defis_file = os.path.join(drive_path, 'no_defis_words.txt')
with open(no_defis_file, 'w', encoding='utf-8') as file:
    for word in no_defis_words:
        file.write(f"{word}\n")

# Шаг 5: Коммит и пуш изменений в репозиторий GitLab
# %cd "{repo_path}"
# !git config --global user.email "your_email@example.com"
# !git config --global user.name "Your Name"
# !git add "{dictionary_file}"
# !git commit -m "Добавлены новые слова с неправильными написаниями в словарь"
# !git push
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/gramota-generation
# [main 5457dad] Добавлены новые слова с неправильными написаниями в словарь
#  1 file changed, 23029 insertions(+)
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 400.00 KiB | 1.78 MiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0), pack-reused 0
# To https://gitlab.gramota.ru/gramotaprojects/gramota-generation.git
#    84d2008..5457dad  main -> main

# %%
import pandas as pd
import os
from google.colab import drive

# Подключаем Google Drive
drive.mount('/content/drive')

# Путь к Google Drive
drive_path = '/content/drive/My Drive'
# Путь к локальному клону репозитория GitLab в Google Drive
repo_path = os.path.join(drive_path, 'gramota-generation')

# GitLab персональный токен доступа
gitlab_token = 'glpat-LPmZie5sw9HTMphcs2BP'

# Если репозиторий ещё не клонирован, клонируем его с использованием токена
if not os.path.exists(repo_path):
    # !git clone https://oauth2:{gitlab_token}@gitlab.gramota.ru/gramotaprojects/gramota-generation.git "{repo_path}"

# Путь к файлу словаря в репозитории
dictionary_file = os.path.join(repo_path, 'opensearch/indexing/alias_titles_slovari.txt')

# Проверяем, что файл словаря существует
if not os.path.exists(dictionary_file):
    raise FileNotFoundError(f"{dictionary_file} не найден. Проверьте, что репозиторий клонирован корректно.")

# Чтение существующего словаря, преобразование в строчные буквы и удаление пустых строк
with open(dictionary_file, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Преобразование в строчные буквы и удаление пустых строк
lines = [line.strip().lower() for line in lines if line.strip()]

# Запись обновленного файла
with open(dictionary_file, 'w', encoding='utf-8') as file:
    for line in lines:
        file.write(f"{line}\n")

# Коммит и пуш изменений в репозиторий GitLab
# %cd "{repo_path}"
# !git config --global user.email "ag15barto@gmail.com"
# !git config --global user.name "Антон Вахранёв"
# !git add "{dictionary_file}"
# !git commit -m "Приведены все слова в словаре к строчным буквам и удалены пустые строки"
# !git push
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/gramota-generation
# [main 95851a4] Приведены все слова в словаре к строчным буквам и удалены пустые строки
#  1 file changed, 23478 insertions(+), 23479 deletions(-)
#  rewrite opensearch/indexing/alias_titles_slovari.txt (74%)
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 404.18 KiB | 2.17 MiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0), pack-reused 0
# To https://gitlab.gramota.ru/gramotaprojects/gramota-generation.git
#    5457dad..95851a4  main -> main

# %%
import pandas as pd
import os
from google.colab import drive

# Подключаем Google Drive
drive.mount('/content/drive')

# Путь к Google Drive
drive_path = '/content/drive/My Drive'
# Путь к локальному клону репозитория GitLab в Google Drive
repo_path = os.path.join(drive_path, 'gramota-generation')

# GitLab персональный токен доступа
gitlab_token = 'glpat-LPmZie5sw9HTMphcs2BP'

# Если репозиторий ещё не клонирован, клонируем его с использованием токена
if not os.path.exists(repo_path):
    # !git clone https://oauth2:{gitlab_token}@gitlab.gramota.ru/gramotaprojects/gramota-generation.git "{repo_path}"

# Путь к файлу словаря в репозитории
dictionary_file = os.path.join(repo_path, 'opensearch/indexing/alias_titles_slovari.txt')

# Проверяем, что файл словаря существует
if not os.path.exists(dictionary_file):
    raise FileNotFoundError(f"{dictionary_file} не найден. Проверьте, что репозиторий клонирован корректно.")

# Чтение существующего словаря, преобразование в строчные буквы и удаление пустых строк и строк с дефисом с пробелами
with open(dictionary_file, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Преобразование в строчные буквы, удаление пустых строк и строк с дефисом с пробелами
lines = [line.strip().lower() for line in lines if line.strip() and ' - ' not in line]

# Запись обновленного файла
with open(dictionary_file, 'w', encoding='utf-8') as file:
    for line in lines:
        file.write(f"{line}\n")

# Путь к файлу notletter.csv
csv_file = os.path.join(drive_path, 'notletter.csv')

# Проверяем, что файл notletter.csv существует
if not os.path.exists(csv_file):
    raise FileNotFoundError(f"{csv_file} не найден. Проверьте, что файл существует в Google Drive.")

# Чтение файла notletter.csv и извлечение слов без дефиса или с дефисом с пробелами перед и после
df = pd.read_csv(csv_file)
df = pd.read_csv(csv_file)
no_defis_words = df[df['name'].str.contains(' - ') | ~df['name'].str.contains('-')]['name'].tolist()

# Путь к файлу no_defis_words.txt
no_defis_file = os.path.join(drive_path, 'no_defis_words.txt')

# Запись слов без дефиса или с дефисом с пробелами в файл
with open(no_defis_file, 'w', encoding='utf-8') as file:
    for word in no_defis_words:
        file.write(f"{word}\n")

# Коммит и пуш изменений в репозиторий GitLab
# %cd "{repo_path}"
# !git config --global user.email "ag15barto@gmail.com"
# !git config --global user.name "Антон Вахранёв"
# !git add "{dictionary_file}"
# !git commit -m "Приведены все слова в словаре к строчным буквам, удалены пустые строки и строки с дефисом с пробелами"
# !git push
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/gramota-generation
# [main 7f68bf6] Приведены все слова в словаре к строчным буквам, удалены пустые строки и строки с дефисом с пробелами
#  1 file changed, 42 deletions(-)
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 699 bytes | 77.00 KiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0), pack-reused 0
# To https://gitlab.gramota.ru/gramotaprojects/gramota-generation.git
#    95851a4..7f68bf6  main -> main

# %%
from google.colab import drive
import pandas as pd
import os

# Подключаем Google Drive
drive.mount('/content/drive')

# Путь к Google Drive
drive_path = '/content/drive/My Drive'
# Путь к файлу notletter.csv
csv_file = os.path.join(drive_path, 'notletter.csv')

# Чтение файла notletter.csv
df = pd.read_csv(csv_file)

# Извлечение слов без дефиса или с дефисом с пробелами перед и после
no_defis_words = df[df['name'].str.contains(' - ') | ~df['name'].str.contains('-')]['name'].tolist()

# Путь к файлу no_defis_words.txt
no_defis_file = os.path.join(drive_path, 'no_defis_words.txt')

# Запись слов без дефиса или с дефисом с пробелами в файл
with open(no_defis_file, 'w', encoding='utf-8') as file:
    for word in no_defis_words:
        file.write(f"{word}\n")

# Загрузка содержимого файла
file_path = '/content/drive/My Drive/no_defis_words.txt'  # замените путь на свой
with open(file_path, 'r', encoding='utf-8') as file:
    content = file.read()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files

uploaded = files.upload()

for filename, content in uploaded.items():
    print(f"Загруженный файл '{filename}' содержит следующее:")
    print(content.decode('utf-8'))
# Out:
# "ГНИЛОЙ́\nДО (ПРЕДЛОГ)\nМЕСИ́́ТЬ\nМЕ́́ССА\nПОД УЗДЦЫ\nСВЯТОЙ́\nУВЕСТИ́́\nВ МЕРУ\nЗА ИСКЛЮЧЕНИЕМ\nНА БАЗЕ\nНА ГРАНИ\nНЕЗАВИСИМО ОТ\nПО ОТНОШЕНИЮ К\nДО (НОТА)\nВ АЖУРЕ\nБАЙХОВЫЙ ЧАЙ\nБИТЬ БАКЛУШИ\nВИНИТЕЛЬНЫЙ ПАДЕЖ\nВИСОКОСНЫЙ ГОД\nПОПАДАТЬ ВПРОСАК\nПОПАСТЬ ВПРОСАК\nГРЕЦКИЙ ОРЕХ\nДАТЕЛЬНЫЙ ПАДЕЖ\nИМЕНИТЕЛЬНЫЙ ПАДЕЖ\nКАНУТЬ В ЛЕТУ\nСБИТЬ С ПАНТАЛЫКУ\nПРЕДЛОЖНЫЙ ПАДЕЖ\nЗНАКИ ПРЕПИНАНИЯ\nРОДИТЕЛЬНЫЙ ПАДЕЖ\nЛЕЗТЬ НА РОЖОН\nТВОРИТЕЛЬНЫЙ ПАДЕЖ\nДВУЛИКИЙ ЯНУС\nНИ БЕЛЬМЕСА НЕ СМЫСЛИТЬ\nНИ БЕЛЬМЕСА НЕ ПОНИМАТЬ\nЗА ШИВОРОТ\nЧЕЛОВЕК КАК ОН ЕСТЬ\nО НЕДОСТАТКАХ ЛЮДЕЙ\nО НЕСХОЖЕСТИ ЛЮДЕЙ\nЧЕЛОВЕК СРЕДИ ДРУГИХ ЛЮДЕЙ\nСРЕДИ ПЛОХИХ И ХОРОШЕМУ ПЛОХО\nВ СЕМЬЕ НЕ БЕЗ УРОДА\nО ТЕХ, КТО ОТ РОДУ ПЛОХ\nВНЕШНИЙ ОБЛИК - ВНУТРЕННИЙ МИР\nКТО ЛУЧШЕ?\nО СХОДСТВЕ ЛЮДЕЙ\nПТИЦЫ ВЫСОКОГО ПОЛЁТА\nО ЛЮДЯХ СРЕДНИХ СПОСОБНОСТЕЙ\nО МАЛОСПОСОБНЫХ ЛЮДЯХ\nО ЗАУРЯДНЫХ ЛЮДЯХ\nО НИКУДЫШНЫХ ЛЮДЯХ\nСКРОМНОСТЬ - ТЩЕСЛАВИЕ\nЧЕСТЬ - БЕСЧЕСТЬЕ. О СЛАВЕ\nО ЧЕСТИ\nПОЧЁТ И УВАЖЕНИЕ\nБОГАТСТВО И СЛАВА\nО КУМИРЕ\nСОВЕСТЬ - НАХАЛЬСТВО\nОТПОВ
# ...
