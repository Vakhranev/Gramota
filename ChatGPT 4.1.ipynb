# %% [markdown]
# <a href="https://colab.research.google.com/github/Vakhranev/Gramota/blob/main/ChatGPT%204.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
from openai import OpenAI

# Установите ваш API-ключ
client = OpenAI(api_key='')

# Список моделей для теста
models = [
    "gpt-4.1-mini",
    "gpt-4.1-nano"
]

# Сообщение, которое будет отправлено каждой модели
messages = [
    {
        "role": "user",
        "content": '''Ответь на вопрос, учитывая информацию с сайта Грамота.ру:
                   "Нужно ли в даннлм случае закрыть причастный оборот перед «И.И.Иванова» с учетом того, что речь идет о названии мероприятия?

Направляется письмо от председателя Конференции по вопросу создания на Ближнем Востоке зоны,
свободной от ядерного и других видов оружия массового уничтожения И.И.Иванова."'''
    }
]

# Запрос и вывод результатов
for model_id in models:
    print(f"\n🔍 Ответ от модели: {model_id}")
    completion = client.chat.completions.create(
        model=model_id,
        messages=messages
    )
    print(completion.choices[0].message.content)
# Out:
# 🔍 Ответ от модели: gpt-4.1-mini
# Согласно нормам русского языка и информации с сайта Грамота.ру, причастный оборот, стоящий перед именем собственным (например, перед фамилией «И.И. Иванова»), обычно необходимо выделять запятой, если он уточняет или поясняет это имя.
#
# В вашем примере:
#
# «Направляется письмо от председателя Конференции по вопросу создания на Ближнем Востоке зоны, свободной от ядерного и других видов оружия массового уничтожения И.И.Иванова.»
#
# Здесь «свободной от ядерного и других видов оружия массового уничтожения» — это причастный (или определительный) оборот, относящийся к слову «зоны».
#
# Но после слова «зоны» сразу следует имя собственное «И.И.Иванова», которое по смыслу является не частью названия зоны, а, очевидно, относится к «председателю Конференции».
#
# В таком случае наличие причастного оборота, непосредственно примыкающего к имени собственному без запятой, может привести к двусмысленности.
#
# ...
